# %% [markdown]
# # RAHENDRA FIRMAN SUNARTAMA
# ## 19.0504.0073

# %% [markdown]
# # Import

# %%
#mengimport Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load

# %%
netflix=pd.read_csv('https://raw.githubusercontent.com/HendraBattousai/MachineLearning/main/netflix_titles.csv')
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Understanding

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#menghapus kolom yang tidak diperlukan
netflix.drop(['director','cast'] ,axis=1 ,inplace=True)

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   country       7976 non-null   object
#  4   date_added    8797 non-null   object
#  5   release_year  8807 non-null   int64
#  6   rating        8803 non-null   object
#  7   duration      8804 non-null   object
#  8   listed_in     8807 non-null   object
#  9   description   8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
netflix.head()
# Out:
#   show_id     type                  title        country          date_added  \
# 0      s1    Movie   Dick Johnson Is Dead  United States  September 25, 2021
# 1      s2  TV Show          Blood & Water   South Africa  September 24, 2021
# 2      s3  TV Show              Ganglands            NaN  September 24, 2021
# 3      s4  TV Show  Jailbirds New Orleans            NaN  September 24, 2021
# 4      s5  TV Show           Kota Factory          India  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# ...

# %%
#didalam kolom country masih NAN,sehingga perlu diganti.saya menganti NAN menjadi US
netflix['country'].replace(np.NaN,'United States', inplace=True)

# %%
netflix
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands  United States
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8802   s8803    Movie                 Zodiac  United States
# 8803   s8804  TV Show            Zombie Dumb  United States
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
#di dalam kolom rating juka memiliki NaN dan saya mengantinya dengan TV-MA
netflix['rating'].replace(np.NaN,'TV-MA', inplace=True)

# %%
netflix
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands  United States
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8802   s8803    Movie                 Zodiac  United States
# 8803   s8804  TV Show            Zombie Dumb  United States
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # Diantara film yang ada di netflix tipe kategori manakah yang paling banyak?

# %%
#menampilkan visualisasi dari data rating di netflix
sns.countplot(netflix['rating'])
sns.countplot(netflix['rating']).set_xticklabels(sns.countplot(netflix['rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(10,13)
plt.title('Rating')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#menampilkan data antara jumlah Movie dan Tv Show dengan disertai rating
plt.figure(figsize=(20,16))
sns.countplot(x='rating',hue='type',data=netflix)
plt.title('menampilkan data antara jumlah Movie dan Tv Show dengan disertai rating')
plt.show();

# %%
#menampilkan data antara jumlah Movie dan Tv Show Saja
sns.countplot(netflix['type'])
fig.set_size_inches(10,10)
plt.title('Type');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Di dalam netflix negara mana yang paling banyak memproduksi Film?

# %%
produksi_film = netflix.groupby('country').count().sort_values('title',ascending=False).head(5)
produksi_film.reset_index(inplace=True)
produksi_film
# Out:
#           country  show_id  type  title  date_added  release_year  rating  \
# 0   United States     3649  3649   3649        3642          3649    3649
# 1           India      972   972    972         972           972     972
# 2  United Kingdom      419   419    419         418           419     419
# 3           Japan      245   245    245         244           245     245
# 4     South Korea      199   199    199         199           199     199
#
#    duration  listed_in  description
# 0      3646       3649         3649
# 1       972        972          972
# 2       419        419          419
# 3       245        245          245
# 4       199        199          199

# %%
plt.bar(produksi_film.country,produksi_film.title);

# %% [markdown]
# # Encode

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
output = lb.fit_transform(netflix['type'])
x1 = lb.fit_transform(netflix['title'])
x2 = lb.fit_transform(netflix['rating'])
x3 = lb.fit_transform(netflix['listed_in'])
print('Title : ',x1)
print('Rating : ',x2) 
print('Genre : ',x3)
print('Output : ',output)
# Out:
# Title :  [1975 1091 2651 ... 8774 8777 8781]
# Rating :  [ 7 11 11 ...  8  6  9]
# Genre :  [274 414 242 ... 207 125 328]
# Output :  [0 1 1 ... 0 0 0]

# %%
x1 = pd.DataFrame(x1)
x1.columns = ['title']
x1.head(5)
# Out:
#    title
# 0   1975
# 1   1091
# 2   2651
# 3   3506
# 4   3861

# %%
x2 = pd.DataFrame(x2)
x2.columns = ['rating']
x2.head(5)
# Out:
#    rating
# 0       7
# 1      11
# 2      11
# 3      11
# 4      11

# %%
x3 = pd.DataFrame(x3)
x3.columns = ['listed_in']
x3.head(5)
# Out:
#    listed_in
# 0        274
# 1        414
# 2        242
# 3        297
# 4        393

# %%
output = pd.DataFrame(output)
output.columns = ['type']
output.head(5)
# Out:
#    type
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1

# %%
Rating = pd.concat([x1,x2,x3],axis = 1, join = 'inner')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(Rating, output, test_size = 0.2 ,random_state =0)

# %%
#Mengaktifkan package untuk klasifikasi KNN dengan mengimport package KNeighbors dari SKlearn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier (n_neighbors=4)

# %%
#Kemudian memasukkan data training pada fungsi klasifikasi untuk KNN
knn.fit(Rating, output)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=4)

# %%
#menentukkan prediksi atau peramalannya
knn.score(Rating,output)
# Out:
# 0.91291018508005

# %%
#menentukkan probabilitas dari prediksi
pred = knn.predict(x_test)
print(pred)
pred.shape
# Out:
# [1 0 0 ... 0 0 1]
# (1762,)

# %%
#import package untuk melihat keakuratan data hasil prediksi dengan data aktualnya
from sklearn.metrics import classification_report, confusion_matrix

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      1248
#            1       0.96      0.77      0.85       514
#
#     accuracy                           0.92      1762
#    macro avg       0.93      0.88      0.90      1762
# weighted avg       0.93      0.92      0.92      1762

# %%
#menampilkan akurasi
print("AKURASI : ",accuracy_score(y_test,y_pred),"   atau   ",round(accuracy_score(y_test,y_pred)*100),"%")
# Out:
# AKURASI :  0.9233825198637912    atau    92 %
